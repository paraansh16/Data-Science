# %% [markdown]
# # EXPERIMENT 3
# * Paraansh Nisar
# * Roll No.:42(old)
# * PRN: 1032220803

# %% [markdown]
# **ENCODING IN PYTHON**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
from sklearn.feature_extraction import FeatureHasher

# %%
df = pd.read_csv('student3.csv')
df1= pd.read_csv('student2.csv')

# %% [markdown]
# One-Hot Encoding

# %%
one_hot_encoding = pd.get_dummies(df,columns=['marks '])
one_hot_encoding
# Out:
#     roll     name class   age  marks _56.75  marks _56.77  marks _59.33  \
# 0      1     anil    TE  22.0         False          True         False
# 1      2     amit    TE  21.0         False         False         False
# 2      3   aniket    BE  19.0         False         False         False
# 3      4  ajinkya    TE  20.0         False         False         False
# 4      5     asha    TE   NaN         False         False         False
# 5      6   ayesha    BE  20.0         False         False         False
# 6      7     amar    BE  19.0         False         False         False
# 7      8    Amita    be  23.0         False         False         False
# 8      9     amol    TE  20.0          True         False         False
# 9      9     amol    TE  20.0          True         False         False
# 10    10    anmol    BE   NaN         False         False         False
# 11    11   surbhi    TE  23.0         False         False         False
# 12    12    Sujay    TE  22.0         False         False         False
# 13    13  subhash    be  21.0         False         False         False
# 14    14   sachin   NaN  21.0         False         False          True
# 15    15  shalini    TE  20.0         False         False         False
#
#     marks _59.77  marks _63.28  marks _63.45  marks _65.34  marks _68.33  \
# 0          False         False         False         False         False
# 1           True         False         False         False         False
# 2          False         False         False         False         False
# 3          False         False         False         False         False
# 4          False          True         False         False         False
# 5          False         False         False         False         False
# 6          False         False         False          True         False
# 7          False         False         False         False          True
# 8          False         False         False         False         False
# 9          False         False         False         False         False
# 10         False         False         False         False         False
# 11         False         False         False         False         False
# 12         False         False         False         False         False
# 13         False         False         False         False         False
# 14         False         False         False         False         False
# 15         False         False          True         False         False
#
#     marks _69.66  marks _74.12  marks _76.88  marks _78.66  marks _88.45
# 0          False         False         False         False         False
# 1          False         False         False         False         False
# 2          False         False          True         False         False
# 3           True         False         False         False         False
# 4          False         False         False         False         False
# 5          False         False         False         False         False
# 6          False         False         False         False         False
# 7          False         False         False         False         False
# 8          False         False         False         False         False
# 9          False         False         False         False         False
# 10         False         False         False          True         False
# 11         False         False         False         False         False
# 12         False          True         False         False         False
# 13         False         False         False         False          True
# 14         False         False         False         False         False
# 15         False         False         False         False         False

# %% [markdown]
# Label Encoding

# %%
label_encoder = LabelEncoder()
df1['encoded_name'] = label_encoder.fit_transform(df1['name'])
df1
# Out:
#    roll     name class  marks   age  encoded_name
# 0     1     anil    TE  56.77  22.0             6
# 1     2     amit    TE  59.77  21.0             2
# 2     3   aniket    BE  76.88  19.0             5
# 3     4  ajinkya    TE  69.66   NaN             0
# 4     5     asha   NaN  63.28  20.0             8
# 5     6   ayesha    BE  49.55  20.0             9
# 6     7     amar    BE    NaN  19.0             1
# 7     8    amita    BE    NaN  23.0             3
# 8     9     amol    TE  56.75  20.0             4
# 9    10    anmol    BE  78.66  21.0             7

# %% [markdown]
# Ordinal Encoding

# %%
sizes = pd.DataFrame({
    'Size': ['Small', 'Large', 'Medium', 'Large', 'Small']
})

categories = [['Small', 'Medium', 'Large']]

ordinal_encoder = OrdinalEncoder(categories=categories)
sizes['Size_encoded'] = ordinal_encoder.fit_transform(sizes[['Size']])
sizes
# Out:
#      Size  Size_encoded
# 0   Small           0.0
# 1   Large           2.0
# 2  Medium           1.0
# 3   Large           2.0
# 4   Small           0.0

# %% [markdown]
# Count Encoding

# %%
count_encoding = sizes['Size'].value_counts()
sizes['size_encode'] = sizes['Size'].map(count_encoding)
sizes
# Out:
#      Size  Size_encoded  size_encode
# 0   Small           0.0            2
# 1   Large           2.0            2
# 2  Medium           1.0            1
# 3   Large           2.0            2
# 4   Small           0.0            2

# %% [markdown]
# Hashing Encoding

# %%
df_dict = df.to_dict(orient='records')
hasher = FeatureHasher(n_features=3, input_type='dict')
df_hashing = hasher.fit_transform(df_dict).toarray()
df_hashing
# Out:
# array([[ -1.  , -34.77,   0.  ],
#        [  1.  , -37.77,   0.  ],
#        [  2.  , -57.88,  -1.  ],
#        [  3.  , -48.66,   0.  ],
#        [  3.  ,    nan,   0.  ],
#        [  5.  ,    nan,  -1.  ],
#        [  6.  , -46.34,  -1.  ],
#        [  8.  , -46.33,   1.  ],
#        [  8.  , -37.75,   0.  ],
#        [  8.  , -37.75,   0.  ],
#        [  9.  ,    nan,  -1.  ],
#        [ 10.  ,    nan,   1.  ],
#        [ 11.  , -52.12,   1.  ],
#        [ 13.  , -67.45,   0.  ],
#        [ 13.  , -38.33,    nan],
#        [ 14.  , -43.45,   1.  ]])
